# %% [markdown]
# # 09-12-2025 Plots for presentaitons - Chembl data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data6 = {"MCF7 24h":3265,
"MCF7 6h":4829 ,
"HEPG2 24h": 154,
"HEPG2 6h":3507,
"HT29 24h":973 ,
"HT29 6h":4765 }

plt.bar(data.keys(), data.values(), color={'blue','green'})
# Out:
# <BarContainer object of 6 artists>
